# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

from pathlib import Path
import pandas as pd

from network_idx.processing.fcc_fixed_speeds import (
    parse_fips_from_filename
    )
from network_idx.config import RAW_DIR_FCC_SPEEDS

# Test individually
parse_fips_from_filename("bdc_01_Cable_fixed_broadband.zip")
# → '01'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# '01'

# %%
# Test structure of final output
parq = r"/home/eprashar_solutions_corelogic_com/network-idx/data/processed/fcc/speeds/fcc_fixed_speeds_AK_02.parquet"
df = pd.read_parquet(parq)
print(df.info())
print(df.head(10))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10499 entries, 0 to 10498
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   state_usps                 10499 non-null  str
#  1   state_fips                 10499 non-null  str
#  2   block_geoid                10499 non-null  str
#  3   cable_location_count       7067 non-null   float64
#  4   cable_provider_count       7067 non-null   float64
#  5   cable_max_download_speed   7067 non-null   float64
#  6   cable_max_upload_speed     7067 non-null   float64
#  7   copper_location_count      8747 non-null   float64
#  8   copper_provider_count      8747 non-null   float64
#  9   copper_max_download_speed  8747 non-null   float64
#  10  copper_max_upload_speed    8747 non-null   float64
#  11  fiber_location_count       3063 non-null   float64
#  12  fiber_provider_count       3063 non-null   float64
# ...

# %%
# Load provider parquet
parquet_path = Path("/home/eprashar_solutions_corelogic_com/network-idx/data/processed/fcc/speeds/fcc_fixed_speeds_providers_AK_02.parquet")
df = pd.read_parquet(parquet_path)
df.head()
# Out:
#   state_usps state_fips      block_geoid         frn provider_id  \
# 0         AK         02  020130001001030  0003739521      131226
# 1         AK         02  020130001001053  0003739521      131226
# 2         AK         02  020130001001076  0003739521      131226
# 3         AK         02  020130001001166  0003739521      131226
# 4         AK         02  020130001001168  0003739521      131226
#
#            brand_name  cable_location_count  cable_max_download_speed  \
# 0  Fastwyre Broadband                   NaN                       NaN
# 1  Fastwyre Broadband                   NaN                       NaN
# 2  Fastwyre Broadband                   NaN                       NaN
# 3  Fastwyre Broadband                   NaN                       NaN
# 4  Fastwyre Broadband                   NaN                       NaN
#
#    cable_max_upload_speed  copper_location_count  copper_max_download_speed  \
# ...
