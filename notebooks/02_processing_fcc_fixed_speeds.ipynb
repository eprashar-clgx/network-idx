# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

import pandas as pd

from network_idx.processing.fcc_fixed_speeds import (
    parse_fips_from_filename,
    get_fips_from_dir,
    extract_zip_file,
    load_csv_to_df,
    aggregate_to_block_geoid
)
from network_idx.config import RAW_DIR_FCC_SPEEDS

# Test individually
parse_fips_from_filename("bdc_01_Cable_fixed_broadband.zip")
# → '01'
# Out:
# '01'

# %%
RAW_DIR_FCC_SPEEDS
# Out:
# WindowsPath('data/raw/fcc/speeds')

# %%
# Test directory parsing
from pathlib import Path
x = Path(r"C:\2026\network-idx\data\raw\fcc\speeds")
get_fips_from_dir(x)
# → ['01', ...]
# Out:
# ['01', '02', '15']

# %%
# Test zip extraction
x = Path(r"C:\2026\network-idx\data\raw\fcc\speeds\bdc_02_Cable_fixed_broadband_J25_03mar2026.zip")
y = Path(r"C:\2026\network-idx\data\extracted\fcc")
extract_zip_file(x,y)
# Out:
# 2026-03-18 15:51:37,517 - INFO - CSV C:\2026\network-idx\data\extracted\fcc\bdc_02_Cable_fixed_broadband_J25_03mar2026.csv already exists. Skipping extraction.
# WindowsPath('C:/2026/network-idx/data/extracted/fcc/bdc_02_Cable_fixed_broadband_J25_03mar2026.csv')

# %%
# Test load df
x = r"C:\2026\network-idx\data\extracted\fcc\bdc_02_Cable_fixed_broadband_J25_03mar2026.csv"
df = load_csv_to_df(x)
print(df.info())
print(df.head(1))
# Out:
# 2026-03-18 15:51:39,085 - INFO - Loading CSV C:\2026\network-idx\data\extracted\fcc\bdc_02_Cable_fixed_broadband_J25_03mar2026.csv into DataFrame
# <class 'pandas.DataFrame'>
# RangeIndex: 163821 entries, 0 to 163820
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   provider_id                    163821 non-null  str
#  1   location_id                    163821 non-null  str
#  2   technology                     163821 non-null  int64
#  3   max_advertised_download_speed  163821 non-null  float64
#  4   max_advertised_upload_speed    163821 non-null  float64
#  5   state_usps                     163821 non-null  str
#  6   block_geoid                    163821 non-null  str
#  7   technology_lbl                 163821 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 16.0 MB
# None
# ...

# %%
# Test aggregation function
processed_df = aggregate_to_block_geoid(df)
print(processed_df.info())
print(processed_df.head(10))
# Out:
# 2026-03-18 15:59:41,789 - INFO - Aggregating data to block_geoid level
# <class 'pandas.DataFrame'>
# RangeIndex: 7067 entries, 0 to 7066
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   block_geoid               7067 non-null   str
#  1   state_usps                7067 non-null   str
#  2   state_fips                7067 non-null   str
#  3   cable_location_count      7067 non-null   int64
#  4   cable_provider_count      7067 non-null   int64
#  5   cable_max_download_speed  7067 non-null   float64
#  6   cable_max_upload_speed    7067 non-null   float64
# dtypes: float64(2), int64(2), str(3)
# memory usage: 520.3 KB
# None
#        block_geoid state_usps state_fips  cable_location_count  \
# 0  020160002001020         AK         02                    45
# 1  020160002001022         AK         02                    21
# ...

# %%
# Test structure of final output
parq = r"C:\2026\network-idx\data\processed\fcc\speeds\fcc_fixed_speeds_AL_01.parquet"
df = pd.read_parquet(parq)
print(df.info())
print(df.head(10))
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 134131 entries, 0 to 134130
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   block_geoid                134131 non-null  str
#  1   state_usps                 134131 non-null  str
#  2   state_fips                 134131 non-null  str
#  3   cable_location_count       95072 non-null   float64
#  4   cable_provider_count       95072 non-null   float64
#  5   cable_max_download_speed   95072 non-null   float64
#  6   cable_max_upload_speed     95072 non-null   float64
#  7   copper_location_count      91528 non-null   float64
#  8   copper_provider_count      91528 non-null   float64
#  9   copper_max_download_speed  91528 non-null   float64
#  10  copper_max_upload_speed    91528 non-null   float64
#  11  fiber_location_count       86597 non-null   float64
#  12  fiber_provider_count       86597 non-null   float64
# ...

# %%
# Check duplicates
dupes = df[df.duplicated()]
print(dupes)
# Out:
# Empty DataFrame
# Columns: [block_geoid, state_usps, state_fips, cable_location_count, cable_provider_count, cable_max_download_speed, cable_max_upload_speed, copper_location_count, copper_provider_count, copper_max_download_speed, copper_max_upload_speed, fiber_location_count, fiber_provider_count, fiber_max_download_speed, fiber_max_upload_speed]
# Index: []
